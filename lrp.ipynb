# %% [markdown]
# [More details with visualization] http://www.heatmapping.org/
# # It tells you which input features were most responsible for a single prediction.
# # Output → Hidden Layers → Input
#
# # YES ->  If you use:
#
# Neural Network (MLP, CNN, LSTM)
# Keras / TensorFlow / PyTorch
#
# # NO —> If you use:
#
# RandomForest
#
# XGBoost
#
# SVM

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import torch.nn as nn
import torch.optim as optim

# %%
train_path = "data/Vegetable Images/train"
test_path = "data/Vegetable Images/test"
val_path = "data/Vegetable Images/validation"

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],   
                         std=[0.229, 0.224, 0.225])    
])

# %%
train_dataset = datasets.ImageFolder(root=train_path, transform=transform)
val_dataset = datasets.ImageFolder(root=val_path, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

# %%
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, len(train_dataset.classes))
# Out:
# s:\Explainable AI\myenv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# s:\Explainable AI\myenv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\Adnan Habib/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:05<00:00, 9.13MB/s]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)


for epoch in range(5):  # increase epochs as needed
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print(f"Epoch {epoch+1}, Loss: {running_loss/len(train_loader)}")
# Out:
# cpu
# Epoch 1, Loss: 0.14935273999052404
# Epoch 2, Loss: 0.0101150520604356
# Epoch 3, Loss: 0.011085245551093161
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 16
#      14 outputs = model(images)
#      15 loss = criterion(outputs, labels)
# ---> 16 loss.backward()
#      17 optimizer.step()
#      18 running_loss += loss.item()
#
# File s:\Explainable AI\myenv\Lib\site-packages\torch\_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# ...

# %% [markdown]
# REST OF THE CODE
#
# https://www.kaggle.com/code/yahabibitoday/lrp-xai/edit

# %%
key = "AIzaSyC7U0K5BcJs5MNce0UM4Pwki1dEwfNfS24" 
from google import genai

 
# Create a client, passing your API key
client = genai.Client(api_key=key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain how AI works in a few words",
)

print(response.text)
# Out:
# AI learns patterns from data to make predictions or decisions.

# %%
# http://localhost:11434

# %%
from flask import Flask, request, jsonify
import subprocess

app = Flask(__name__)

@app.route('/query', methods=['POST'])
def query_model():
    user_input = request.json.get('input')
    if not user_input:
        return jsonify({'error': 'No input provided'}), 400

    # Call ollama CLI with user_input
    # You may want to adjust this to keep the process alive for performance
    result = subprocess.run(['ollama', 'run', 'gemma3:4b'], input=user_input.encode(), capture_output=True)
    response_text = result.stdout.decode()

    return jsonify({'response': response_text})

if __name__ == '__main__':
    app.run(port=5000)
